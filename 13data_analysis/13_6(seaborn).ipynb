# %%
## data visualizaiton with seaborn 
# seaborn is apython visualizatio library based on mtplotlib that provides a high level interface for drawing attratiove and infromationsal statistical graphics seaborn helps in creating complex visualiztion with just few lines of code in this we will learn about it

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
##basic plotting with seaborn
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
### create a scatterplot

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("scatterplot for total bill and tips")
# Out:
# Text(0.5, 1.0, 'scatterplot for total bill and tips')

# %%
##line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Total bill by size')
# Out:
# Text(0.5, 1.0, 'Total bill by size')

# %%
### categorical plots
## bar
sns.barplot(x = 'day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## box plot (used for outliers)
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##violin plot
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### histogram 
sns.histplot(tips['total_bill'],bins=10, kde=True)## kde = is for curve(full form of kde is kernal density estimator)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
###KDE plots
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
### pair plot 
sns.pairplot(tips)

# %%
#heatmap
corr=tips[['total_bill','tip','size']].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import pandas as pd

# %%
df=pd.read_csv('Sales_data.csv')
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
### plot total sales by product 
plt.figure(figsize=(10,5))
sns.barplot(x='Product Category',y='Total Revenue',data=df,estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Revenue'>
